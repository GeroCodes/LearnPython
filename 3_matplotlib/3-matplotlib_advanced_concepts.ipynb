# %% [markdown]
# # MATPLOTLIB: DATA VISUALIZATION

# %% [markdown]
# ## #1 Advanced concepts for subplots

# %%
import numpy as np
import matplotlib.pyplot as plt

#use %matplotlib inline to plot within a notebook
# %matplotlib inline

#use plt.show() after every plot-method to plot within an editor
#plt.show()

# %%
#create a dataset
x = np.linspace(0,5,11)
y = x**2

print(x)
print(y)
# Out:
# [0.  0.5 1.  1.5 2.  2.5 3.  3.5 4.  4.5 5. ]
# [ 0.    0.25  1.    2.25  4.    6.25  9.   12.25 16.   20.25 25.  ]

# %% [markdown]
# ### Subplot2Grid

# %%
#create a figure
fig = plt.figure()

#create axes on the figure
#use colspan and rowspan to determine size
#.subplot2grid((total rows, total cols), (start row, start col), width/height)
ax1 = plt.subplot2grid((3,3),(0,0), colspan=3)
ax2 = plt.subplot2grid((3,3),(1,0), colspan=2)
ax3 = plt.subplot2grid((3,3),(1,2), rowspan=2)
ax4 = plt.subplot2grid((3,3),(2,0))
ax5 = plt.subplot2grid((3,3),(2,1))

# %% [markdown]
# ### Gridspec

# %%
import matplotlib.gridspec as gridspec

#create a figure
fig = plt.figure()

#create gridspec
gs = gridspec.GridSpec(2,3, height_ratios=[2,1], width_ratios=[1,2,1])

for g in gs:
    ax = fig.add_subplot(g)
